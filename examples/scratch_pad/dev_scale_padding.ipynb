# %%
# This allows multiple outputs from a single jupyter notebook cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %matplotlib inline
import pandas as pd

# %%
idf = pd.read_csv('../data/SPY_20110701_20120630_Bollinger.csv',index_col=0,parse_dates=True)
idf.shape
idf.head(3)
idf.tail(3)
# Out:
# (252, 9)
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-07-01  132.089996  134.100006  131.779999  133.919998  117.161659
# 2011-07-05  133.779999  134.080002  133.389999  133.809998  117.065437
# 2011-07-06  133.490005  134.139999  133.110001  133.970001  117.205429
#
#                Volume      UpperB      LowerB  PercentB
# Date
# 2011-07-01  202385700  132.373927  125.316073  1.219057
# 2011-07-05  165936000  133.254297  124.912703  1.066618
# 2011-07-06  143331600  134.040915  124.627085  0.992467
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-06-27  132.419998  133.429993  131.970001  133.169998  118.980804
# 2012-06-28  132.289993  132.990005  131.279999  132.789993  118.641281
# 2012-06-29  135.199997  136.270004  134.850006  136.100006  121.598610
#
#                Volume      UpperB      LowerB  PercentB
# Date
# 2012-06-27  108088000  136.447962  128.140042  0.605441
# ...

# %%
df = idf.loc['2011-07-01':'2011-12-30',:]

# %%
d = dict(left=0.7,right=0.8,top=1.2,bot=0.9)
d
# Out:
# {'left': 0.7, 'right': 0.8, 'top': 1.2, 'bot': 0.9}

# %%
z = {'left': 0.7, 'right': 0.8, 'top': 1.2, 'bot': 0.9, 'right': 0.9}

# %%
z
# Out:
# {'left': 0.7, 'right': 0.9, 'top': 1.2, 'bot': 0.9}

# %%
'left' in d
# Out:
# True

# %%
'bottom' in d
# Out:
# False

# %%
keys=('left','right','top','bottom')
for x in d:
    x in keys
    print(d[x])
# Out:
# True
# 0.7
# True
# 0.8
# True
# 1.2
# False
# 0.9

# %%
x = 5
isinstance(x,float)
# Out:
# False

# %%
import mplfinance as mpf
mpf.__version__
#mpf.plot(df,volume=True,scale_padding=dict(left=0.1,right=0.05),tight_layout=True)
mpf.plot(df,volume=True,tight_layout=True)
# Out:
# '0.12.6a2'

# %%
STOP HERE
# Out:
#   File "<ipython-input-13-a6774c8535dd>", line 1
#     STOP HERE
#             ^
# SyntaxError: invalid syntax

# %%
x = 1.5
a = b = c = d = x

# %%
a
b
c
d

# %%
a *= 0.4
b *= 0.4
c *= 0.4
d *= 0.4
a
b
c
d

# %%
a = 1.1
b = 1.2
c = 1.3
d = 1.4
a
b
c
d

# %% [markdown]
# ---
#
# #### We can switch which panel is main and which contains volume:

# %%
mpf.plot(df,type='candle',volume=True,main_panel=1,volume_panel=0)

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

# %%
import matplotlib as mpl

# %%
isinstance(ax,mpl.axes.Axes)

# %%
isinstance(fig,mpl.figure.Figure)

# %%
fig = plt.figure()
isinstance(fig,mpl.figure.Figure)

# %%
ax = fig.add_axes([0.15,0.18,0.7,0.7])

# %%
isinstance(ax,mpl.axes.Axes)

# %%
ax2 = fig.add_axes([0.15,0.18,0.7,0.7],sharex=ax)

# %%
isinstance(ax2,mpl.axes.Axes)

# %%
axlist = fig.get_axes()

# %%
axlist

# %%
fig, ax = plt.subplots()

# %%
axlist = fig.get_axes()

# %%
axlist

# %%
ax

# %%
ax == axlist[0]

# %%
a = [ax,ax,ax]

# %%
all([x is None for x in a])

# %%
all(isinstance(x,mpl.axes.Axes) for x in a)

# %%
ap = [mpf.make_addplot(df['High'],ax=ax),
      mpf.make_addplot(df['Low'],ax=ax)
     ]
#mpf.plot(df,volume=False,ax=None,addplot=ap)
mpf.plot(df,volume=False,ax=ax,addplot=ap,fig=fig)
mpf.plot(df,volume=False,fig=fig)
#mpf.plot(df,volume=False)#,addplot=ap)
