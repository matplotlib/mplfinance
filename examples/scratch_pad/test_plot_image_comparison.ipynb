# %%
# %load addplot.py
#!/usr/bin/env python


import pandas as pd
pd.__version__  # for the record


df = pd.read_csv('data/SPY_20110701_20120630_Bollinger.csv',index_col=0,parse_dates=True)
df.shape
df.head(3)
df.tail(3)


import mplfinance as mpf
mpf.plot(df,volume=True,savefig='test01.jpg')


#apdict = mpf.make_addplot(df['LowerB'])
#mpf.plot(df,volume=True,addplot=apdict)

#apd = mpf.make_addplot(df['LowerB'],scatter=True)
#mpf.plot(df,addplot=apd,savefig='test02.jpg')

# %%
from PIL import Image

# %%
img01 = Image.open('test01.jpg')

# %%
img01ref= Image.open('test01ref.jpg')

# %%
img01 == img01ref
# Out:
# True

# %%
img01reft = Image.open('test01.testref.jpg')

# %%
img01ref == img01reft
# Out:
# True

# %%
from PIL import ImageChops

# %%
diff = ImageChops.difference(img01,img01ref)

# %%
diff.getbbox()
# Out:
# (40, 48, 576, 414)

# %%
if diff.getbbox():
    print('diff')
# Out:
# diff

# %%
img01.save(open('i1.jpg','wb'))

# %%
img01ref.save(open('i1r.jpg','wb'))

# %%
i1 = Image.open('i1.jpg')

# %%
i1r = Image.open('i1r.jpg')

# %%
i1 == i1r
# Out:
# False

# %%
h1 = img01.histogram()

# %%
h1r = img01ref.histogram()

# %%
import math
from functools import reduce
import operator

# %%
h1rt = img01reft.histogram()

# %%
rms = math.sqrt(reduce(operator.add,
                       map(lambda a,b: (a-b)**2, h1, h1rt))/len(h1))

# %%
rms
# Out:
# 8145.764864748481

# %%
h = ImageChops.difference(img01,img01reft).histogram()

# %%
rms = math.sqrt(reduce(operator.add,
                       map(lambda h,i: h*(i**2), h, range(256)))/ 
                (float(img01.size[0]) * img01.size[1]))

# %%
rms
# Out:
# 71.60327235738107

# %%
# %ls -l *.jpg
# Out:
# -rw-rw-r-- 1 goldfarb general 51699 Feb 13 12:29 test01.jpg
# -rw-rw-r-- 1 goldfarb general 51699 Feb 13 12:28 test01ref.jpg

# %%
from IPython.display import Image
Image(filename='test01.jpg')

# %%
Image(filename='test01ref.jpg')

# %%
# !/bb/mbig/mbig5/jupven/dinotools/rcparams backend
# Out:
#                                                     Value
# rcParams Key
# backend           module://ipykernel.pylab.backend_inline
# backend_fallback                                     True

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['backend'] = 'TkAgg'

# %%
plt.rcParams['backend']
# Out:
# 'TkAgg'
