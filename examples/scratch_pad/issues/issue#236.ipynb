# %%
# This allows multiple outputs from a single jupyter notebook cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %matplotlib inline
import pandas as pd
pd.__version__  # for the record
# Out:
# '1.0.5'

# %%
import pickle
import mplfinance as fplt
import pandas as pd
df = pickle.load(open("issue236.df.data", "rb"))

# %%
#df.head()

# %%
df = pd.read_csv('issue236.df.scratchdata',index_col=0,parse_dates=True)

# %%
df
# Out:
#                              Open    High     Low   Close   Volume  AdjClose
# Date
# 2020-08-11 04:00:00-04:00  336.93  337.13  336.93  337.05  15800.0  337.0059
# 2020-08-11 04:01:00-04:00  337.00  337.04  336.99  336.99   3330.0  337.0265
# 2020-08-11 04:02:00-04:00  336.84  336.85  336.84  336.85   4378.0  336.8499
# 2020-08-11 04:04:00-04:00  336.84  336.84  336.79  336.79    400.0  336.8150
# 2020-08-11 04:07:00-04:00  336.88  336.89  336.88  336.88  40800.0  336.8898

# %%
df.index
# Out:
# DatetimeIndex(['2020-08-11 04:00:00-04:00', '2020-08-11 04:01:00-04:00',
#                '2020-08-11 04:02:00-04:00', '2020-08-11 04:04:00-04:00',
#                '2020-08-11 04:07:00-04:00'],
#               dtype='datetime64[ns, pytz.FixedOffset(-240)]', name='Date', freq=None)

# %%
df.index.values
# Out:
# array(['2020-08-11T08:00:00.000000000', '2020-08-11T08:01:00.000000000',
#        '2020-08-11T08:02:00.000000000', '2020-08-11T08:04:00.000000000',
#        '2020-08-11T08:07:00.000000000'], dtype='datetime64[ns]')

# %%
print(df)
fplt.plot(df,type='candle',style='charles',title='SPY',ylabel='Price ($)',figscale=0.75)
# Out:
#                              Open    High     Low   Close   Volume  AdjClose
# Date
# 2020-08-11 04:00:00-04:00  336.93  337.13  336.93  337.05  15800.0  337.0059
# 2020-08-11 04:01:00-04:00  337.00  337.04  336.99  336.99   3330.0  337.0265
# 2020-08-11 04:02:00-04:00  336.84  336.85  336.84  336.85   4378.0  336.8499
# 2020-08-11 04:04:00-04:00  336.84  336.84  336.79  336.79    400.0  336.8150
# 2020-08-11 04:07:00-04:00  336.88  336.89  336.88  336.88  40800.0  336.8898

# %%
sdf = df['Close']
sdf
sdf.plot()
# Out:
# Date
# 2020-08-11 04:00:00-04:00    337.05
# 2020-08-11 04:01:00-04:00    336.99
# 2020-08-11 04:02:00-04:00    336.85
# 2020-08-11 04:04:00-04:00    336.79
# 2020-08-11 04:07:00-04:00    336.88
# Name: Close, dtype: float64
# /home/dino/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.pyplot as plt

# %%
x = df.index.values
y = df.Close.values
x
y
# Out:
# array(['2020-08-11T08:00:00.000000000', '2020-08-11T08:01:00.000000000',
#        '2020-08-11T08:02:00.000000000', '2020-08-11T08:04:00.000000000',
#        '2020-08-11T08:07:00.000000000'], dtype='datetime64[ns]')
# array([337.05, 336.99, 336.85, 336.79, 336.88])

# %%
plt.plot(x,y)

# %%
sdf.index
# Out:
# DatetimeIndex(['2020-08-11 04:00:00-04:00', '2020-08-11 04:01:00-04:00',
#                '2020-08-11 04:02:00-04:00', '2020-08-11 04:04:00-04:00',
#                '2020-08-11 04:07:00-04:00'],
#               dtype='datetime64[ns, pytz.FixedOffset(-240)]', name='Date', freq=None)

# %%
dts = sdf.index.to_pydatetime()

# %%
type(dts)
dts
# Out:
# numpy.ndarray
# array([datetime.datetime(2020, 8, 11, 4, 0, tzinfo=pytz.FixedOffset(-240)),
#        datetime.datetime(2020, 8, 11, 4, 1, tzinfo=pytz.FixedOffset(-240)),
#        datetime.datetime(2020, 8, 11, 4, 2, tzinfo=pytz.FixedOffset(-240)),
#        datetime.datetime(2020, 8, 11, 4, 4, tzinfo=pytz.FixedOffset(-240)),
#        datetime.datetime(2020, 8, 11, 4, 7, tzinfo=pytz.FixedOffset(-240))],
#       dtype=object)

# %%
for ix, d in enumerate(dts):
    dts[ix] = d.replace(tzinfo=None)

# %%
dts
# Out:
# array([datetime.datetime(2020, 8, 11, 4, 0),
#        datetime.datetime(2020, 8, 11, 4, 1),
#        datetime.datetime(2020, 8, 11, 4, 2),
#        datetime.datetime(2020, 8, 11, 4, 4),
#        datetime.datetime(2020, 8, 11, 4, 7)], dtype=object)

# %%
x = dts
y = df.Close.values

# %%
plt.plot(x,y)
