# %%
import sqlite3
import pandas as pd
import numpy as np
from sql_metadata import Parser
from traceback import format_exc
import time

# %%
# This allows multiple outputs from a single jupyter notebook cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
FIRST_TIME = True

FLAG_DEBUG = False # True # 

RSI_PERIOD, RSI_AVG, RSI_BAND_WIDTH = 100, 25, 0.6
EMA_FAST, EMA_SLOW, EMA_LONG = 15, 50, 150
EMA_FAST_SCALE = 1.4  # EMA10 band half-width factor
EMA_SLOW_SCALE = 2.0 
MA_VOL = 20
SPAN, OVERLAP = 200, 15
PANID_PRICE, PANID_VOL, PANID_RSI, PANID_SIGNAL = 0, 3, 2, 1
PANEL_RATIOS = (8, 1, 8, 1)
FIGURE_WIDTH, FIGURE_HEIGHT =  17, 13
YELLOW = '#F5D928'
LIGHT_BLACK = '#8F8E83'

# %%
CHART_TABLE_NAME = "quote_ta"
db_name = "SP500"
file_tickers = "wl_index-SPY_SP500.csv"
file_dict = "ticker-catalog.csv"
file_db = f"db_{db_name}.sqlite"

# %%
def _load_stooq_data(file_path):
    """Load historical quotes from http://stooq.com/db/h
    and parse it to Pandas dataframe
    """
    df = pd.read_csv(file_path,index_col=2,parse_dates=False)
    df.reset_index(inplace=True)
    df.drop(columns=['<TICKER>', '<PER>', '<TIME>','<OPENINT>'], axis=1, inplace=True)
    # Avoid reserved words like date, open via suffix '_' for original quotes
    df.rename(columns={'<DATE>' : "date_", '<OPEN>': "open_", '<HIGH>':"high_", 
                   '<LOW>':"low_", '<CLOSE>':"close_", '<VOL>':"volume_"} ,inplace=True)
    df.set_index("date_", inplace=True)
    return df


def _ta_RSI(df, n=14):
    """Calculate Technical Analysis indicator RSI, 0-centered
    """
    # https://github.com/wgong/mplfinance/blob/master/examples/rsi.py
    diff = df.w_p.diff().values
    gains = diff
    losses = -diff
    with np.errstate(invalid='ignore'):
        gains[(gains<0)|np.isnan(gains)] = 0.0
        losses[(losses<=0)|np.isnan(losses)] = 1e-10 # we don't want divide by zero/NaN
    m = (n-1) / n
    ni = 1 / n
    g = gains[n] = np.nanmean(gains[:n])
    l = losses[n] = np.nanmean(losses[:n])
    gains[:n] = losses[:n] = np.nan
    for i,v in enumerate(gains[n:],n):
        g = gains[i] = ni*v + m*g
    for i,v in enumerate(losses[n:],n):
        l = losses[i] = ni*v + m*l
    rs = gains / losses
    return 50 - (100/(1+rs))



def _calculate_ta(df,rsi_period=RSI_PERIOD, avg_period=RSI_AVG, band_width=RSI_BAND_WIDTH):
    """Calculate Technical Analysis indicators such as 
        - EMA (fast,slow,long), EMA-band, 
        - RSI, RSI-band,
        - Vol-avg
    """
    
    df["w_p"] = 0.25*(2*df["close_"] + df["high_"] + df["low_"])
    df["ema_fast"] = df.w_p.ewm(span=EMA_FAST).mean()
    df["ema_slow"] = df.w_p.ewm(span=EMA_SLOW).mean()
    df["ema_long"] = df.w_p.ewm(span=EMA_LONG).mean()

    # range
    hl_mean_fast = (df.high_ - df.low_).ewm(span=int(EMA_FAST/2)).mean()
    df["ema_fast_u"] =  df.ema_fast + 0.5*hl_mean_fast * EMA_FAST_SCALE
    df["ema_fast_d"] =  df.ema_fast - 0.5*hl_mean_fast * EMA_FAST_SCALE

    hl_mean_slow = (df.high_ - df.low_).ewm(span=int(EMA_SLOW/2)).mean()
    df["ema_slow_u"] =  df.ema_slow + 0.5*hl_mean_slow * EMA_SLOW_SCALE
    df["ema_slow_d"] =  df.ema_slow - 0.5*hl_mean_slow * EMA_SLOW_SCALE

    # trim volume to avoid exponential form
    df['vol'] = df['volume_'] / 1000000.0
    df["vol_avg"] = df.vol.ewm(span=MA_VOL).mean()

    df["rsi"] = _ta_RSI(df,n=rsi_period)
    df["rsi_avg"] = df.rsi.ewm(span=avg_period).mean()
    df["rsi_u"] = df["rsi_avg"] + band_width 
    df["rsi_d"] = df['rsi_avg'] - band_width 
    df["rsi_signal"] = df["rsi"] - df["rsi_avg"]
    
    df["del_ema_slow"] = df.ema_slow.diff().values
    df["del_ema_long"] = df.ema_long.diff().values
    df["del_rsi_avg"] = df.rsi_avg.diff().values
    
    return df

def _display_df(df, nrows=3):
    print(df.head(nrows))
    print("\n",3*"..","\n")
    print(df.tail(nrows))

# %%
create_table_sql = f'''CREATE TABLE {CHART_TABLE_NAME}
    (ticker text
    
    , date_ text
	, open_ real
	, high_ real
	, low_ real
	, close_ real
	, volume_ INTEGER
    
	, w_p real
	, ema_fast real
	, ema_slow real
	, ema_long real
	, ema_fast_u real
	, ema_fast_d real
	, ema_slow_u real
	, ema_slow_d real
	, vol real
	, vol_avg real
	, rsi real
	, rsi_avg real
	, rsi_u real
	, rsi_d real
	, rsi_signal real
	, del_ema_slow real
	, del_ema_long real
	, del_rsi_avg real 
)
'''

# https://www.tutorialspoint.com/sqlite/sqlite_indexes.htm
create_index_sql = f'''
Create unique index if not exists
ticker_dt on {CHART_TABLE_NAME} ( ticker , date_ )
'''

# %%
parser = Parser(create_table_sql)
table_name = parser.tables[0]
table_columns = parser.columns   # open is a key-word, skipped
print(f"table_name: {table_name} \n\ncolumns: {table_columns}")
# Out:
# table_name: quote_ta
#
# columns: ['ticker', 'date_', 'open_', 'high_', 'low_', 'close_', 'volume_', 'w_p', 'ema_fast', 'ema_slow', 'ema_long', 'ema_fast_u', 'ema_fast_d', 'ema_slow_u', 'ema_slow_d', 'vol', 'vol_avg', 'rsi', 'rsi_avg', 'rsi_u', 'rsi_d', 'rsi_signal', 'del_ema_slow', 'del_ema_long', 'del_rsi_avg']

# %%
numeric_cols = ['w_p', 'ema_fast', 'ema_slow', 'ema_long', 'ema_fast_u', 'ema_fast_d', 'ema_slow_u', 'ema_slow_d', 
                'vol', 'vol_avg', 'rsi', 'rsi_avg', 'rsi_u', 'rsi_d', 'rsi_signal', 
                'del_ema_slow', 'del_ema_long', 'del_rsi_avg']

# %% [markdown]
# #### Create table if first-time

# %%
if FIRST_TIME:
    conn = sqlite3.connect(file_db)
    cur = conn.cursor()

    # Create table
    cur.execute(create_table_sql)

    conn.commit()
    conn.close()

# %%
df_ticker = pd.read_csv(file_tickers)
df_meta = pd.read_csv(file_dict)

# %%
_display_df(df_ticker)
# Out:
#   Ticker
# 0    SPY
# 1    XLE
# 2    XLB
#
#  ......
#
#     Ticker
# 497   ZBRA
# 498   ZION
# 499    ZTS

# %%
tickers = df_ticker["Ticker"].to_list()

# %%
len(tickers), tickers[:5]
# Out:
# (500, ['SPY', 'XLE', 'XLB', 'XME', 'XLK'])

# %%
conn = sqlite3.connect(file_db)

# %%
delta_ts = 0
for ticker in tickers:
    ts_begin = time.time()
    
    try:
        dd = df_meta[df_meta['ticker'] == ticker].to_dict('records')[0]
    except:
        print(f"ticker: {ticker}\n{format_exc()}")
        continue
    
    # load quotes, TA, round
    try:
        df = _load_stooq_data(dd['file_path'])
    except:
        print(f"ticker: {ticker}\nfile_path: {dd['file_path']}\n{format_exc()}")
        continue
        
    df = _calculate_ta(df)
    df[numeric_cols] = np.round(df[numeric_cols], 4)
    df.reset_index(inplace=True)
    df['ticker'] = ticker
    
    # save to Sqlite
    df.to_sql(table_name, conn, if_exists='append', index=False)
    ts_end = time.time()
    print(f"ticker = {ticker} done in {(ts_end-ts_begin):.2f} sec")
    delta_ts += (ts_end-ts_begin)
    
print(f"number of tickers={len(tickers)}, calculations done in {delta_ts:.2f} sec")
# Out:
# ticker = SPY done in 0.26 sec
# ticker = XLE done in 0.23 sec
# ticker = XLB done in 0.15 sec
# ticker = XME done in 0.14 sec
# ticker = XLK done in 0.13 sec
# ticker = XLF done in 0.16 sec
# ticker = XLV done in 0.20 sec
# ticker = XLI done in 0.17 sec
# ticker = XLP done in 0.14 sec
# ticker = XLY done in 0.14 sec
# ticker = XLC done in 0.10 sec
# ticker = XLU done in 0.14 sec
# ticker = XLRE done in 0.08 sec
# ticker = A done in 0.15 sec
# ticker = AAL done in 0.12 sec
# ticker = AAP done in 0.17 sec
# ticker = AAPL done in 0.29 sec
# ticker = ABBV done in 0.12 sec
# ticker = ABC done in 0.18 sec
# ticker = ABMD done in 0.12 sec
# ticker = ABT done in 0.26 sec
# ticker = ACN done in 0.12 sec
# ticker = ADBE done in 0.22 sec
# ticker = ADI done in 0.24 sec
# ticker = ADM done in 0.21 sec
# ticker = ADP done in 0.26 sec
# ticker = ADSK done in 0.25 sec
# ticker = AEE done in 0.23 sec
# ticker = AEP done in 0.32 sec
# ticker = AES done in 0.20 sec
# ticker = AFL done in 0.23 sec
# ticker = AIG done in 0.25 sec
# ticker = AIV done in 0.17 sec
# ticker = AIZ done in 0.12 sec
# ticker = AJG done in 0.14 sec
# ticker = AKAM done in 0.12 sec
# ticker = ALB done in 0.12 sec
# ticker = ALGN done in 0.13 sec
# ticker = ALK done in 0.13 sec
# ticker = ALL done in 0.18 sec
# ticker = ALLE done in 0.14 sec
# ticker = AMAT done in 0.26 sec
# ticker = AMCR done in 0.05 sec
# ticker = AMD done in 0.21 sec
# ticker = AME done in 0.15 sec
# ticker = AMGN done in 0.22 sec
# ticker = AMP done in 0.14 sec
# ticker = AMT done in 0.15 sec
# ticker = AMZN done in 0.16 sec
# ticker = ANET done in 0.08 sec
# ticker = ANSS done in 0.11 sec
# ticker = ANTM done in 0.20 sec
# ticker = AON done in 0.12 sec
# ticker = AOS done in 0.12 sec
# ticker = APA done in 0.28 sec
# ticker = APD done in 0.21 sec
# ticker = APH done in 0.12 sec
# ticker = APTV done in 0.11 sec
# ticker = ARE done in 0.12 sec
# ticker = ATO done in 0.13 sec
# ticker = ATVI done in 0.13 sec
# ticker = AVB done in 0.15 sec
# ticker = AVGO done in 0.10 sec
# ticker = AVY done in 0.22 sec
# ticker = AWK done in 0.13 sec
# ticker = AXP done in 0.27 sec
# ticker = AZO done in 0.19 sec
# ticker = BA done in 0.31 sec
# ticker = BAC done in 0.22 sec
# ticker = BAX done in 0.23 sec
# ticker = BBY done in 0.21 sec
# ticker = BDX done in 0.24 sec
# ticker = BEN done in 0.21 sec
# ticker = BIIB done in 0.20 sec
# ticker = BIO done in 0.12 sec
# ticker = BK done in 0.22 sec
# ticker = BKNG done in 0.20 sec
# ticker = BKR done in 0.15 sec
# ticker = BLK done in 0.22 sec
# ticker = BLL done in 0.34 sec
# ticker = BMY done in 0.36 sec
# ticker = BR done in 0.13 sec
# ticker = BSX done in 0.20 sec
# ticker = BWA done in 0.13 sec
# ticker = BXP done in 0.12 sec
# ticker = C done in 0.30 sec
# ticker = CAG done in 0.21 sec
# ticker = CAH done in 0.21 sec
# ticker = CARR done in 0.09 sec
# ticker = CAT done in 0.30 sec
# ticker = CB done in 0.19 sec
# ticker = CBOE done in 0.10 sec
# ticker = CBRE done in 0.11 sec
# ticker = CCI done in 0.12 sec
# ticker = CCL done in 0.21 sec
# ticker = CDNS done in 0.11 sec
# ticker = CDW done in 0.08 sec
# ticker = CE done in 0.12 sec
# ticker = CERN done in 0.17 sec
# ticker = CF done in 0.12 sec
# ticker = CFG done in 0.07 sec
# ticker = CHD done in 0.12 sec
# ticker = CHRW done in 0.17 sec
# ticker = CHTR done in 0.11 sec
# ticker = CI done in 0.25 sec
# ticker = CINF done in 0.21 sec
# ticker = CL done in 0.25 sec
# ticker = CLX done in 0.28 sec
# ticker = CMA done in 0.19 sec
# ticker = CMCSA done in 0.21 sec
# ticker = CME done in 0.12 sec
# ticker = CMG done in 0.12 sec
# ticker = CMI done in 0.21 sec
# ticker = CMS done in 0.24 sec
# ticker = CNC done in 0.13 sec
# ticker = CNP done in 0.31 sec
# ticker = COF done in 0.16 sec
# ticker = COO done in 0.14 sec
# ticker = COP done in 0.24 sec
# ticker = COST done in 0.20 sec
# ticker = COTY done in 0.09 sec
# ticker = CPB done in 0.27 sec
# ticker = CPRT done in 0.12 sec
# ticker = CRM done in 0.12 sec
# ticker = CSCO done in 0.20 sec
# ticker = CSX done in 0.24 sec
# ticker = CTAS done in 0.23 sec
# ticker = CTSH done in 0.11 sec
# ticker = CTVA done in 0.05 sec
# ticker = CTXS done in 0.17 sec
# ticker = CVS done in 0.21 sec
# ticker = CVX done in 0.29 sec
# ticker = D done in 0.22 sec
# ticker = DAL done in 0.23 sec
# ticker = DD done in 0.30 sec
# ticker = DE done in 0.22 sec
# ticker = DFS done in 0.16 sec
# ticker = DG done in 0.11 sec
# ticker = DGX done in 0.16 sec
# ticker = DHI done in 0.13 sec
# ticker = DHR done in 0.22 sec
# ticker = DIS done in 0.36 sec
# ticker = DISCA done in 0.12 sec
# ticker = DISCK done in 0.10 sec
# ticker = DISH done in 0.16 sec
# ticker = DLR done in 0.15 sec
# ticker = DLTR done in 0.16 sec
# ticker = DOV done in 0.20 sec
# ticker = DOW done in 0.07 sec
# ticker = DPZ done in 0.12 sec
# ticker = DRE done in 0.13 sec
# ticker = DRI done in 0.18 sec
# ticker = DTE done in 0.30 sec
# ticker = DUK done in 0.21 sec
# ticker = DVA done in 0.16 sec
# ticker = DVN done in 0.17 sec
# ticker = DXC done in 0.07 sec
# ticker = DXCM done in 0.11 sec
# ticker = EA done in 0.12 sec
# ticker = EBAY done in 0.15 sec
# ticker = ECL done in 0.19 sec
# ticker = ED done in 0.32 sec
# ticker = EFX done in 0.19 sec
# ticker = EIX done in 0.26 sec
# ticker = EL done in 0.12 sec
# ticker = EMN done in 0.17 sec
# ticker = EMR done in 0.24 sec
# ticker = EOG done in 0.19 sec
# ticker = EQIX done in 0.14 sec
# ticker = EQR done in 0.18 sec
# ticker = ES done in 0.13 sec
# ticker = ESS done in 0.12 sec
# ticker = ETN done in 0.22 sec
# ticker = ETR done in 0.22 sec
# ticker = EVRG done in 0.15 sec
# ticker = EW done in 0.14 sec
# ticker = EXC done in 0.24 sec
# ticker = EXPD done in 0.21 sec
# ticker = EXPE done in 0.13 sec
# ticker = EXR done in 0.12 sec
# ticker = F done in 0.28 sec
# ticker = FANG done in 0.08 sec
# ticker = FAST done in 0.19 sec
# ticker = FB done in 0.12 sec
# ticker = FBHS done in 0.09 sec
# ticker = FCX done in 0.17 sec
# ticker = FDX done in 0.25 sec
# ticker = FE done in 0.17 sec
# ticker = FFIV done in 0.12 sec
# ticker = FIS done in 0.18 sec
# ticker = FISV done in 0.19 sec
# ticker = FITB done in 0.18 sec
# ticker = FLS done in 0.14 sec
# ticker = FLT done in 0.09 sec
# ticker = FMC done in 0.12 sec
# ticker = FOX done in 0.06 sec
# ticker = FOXA done in 0.05 sec
# ticker = FRC done in 0.10 sec
# ticker = FRT done in 0.13 sec
# ticker = FTI done in 0.12 sec
# ticker = FTNT done in 0.10 sec
# ticker = FTV done in 0.07 sec
# ticker = GD done in 0.29 sec
# ticker = GE done in 0.34 sec
# ticker = GILD done in 0.23 sec
# ticker = GIS done in 0.24 sec
# ticker = GL done in 0.22 sec
# ticker = GLW done in 0.24 sec
# ticker = GM done in 0.11 sec
# ticker = GOOG done in 0.08 sec
# ticker = GOOGL done in 0.13 sec
# ticker = GPC done in 0.23 sec
# ticker = GPN done in 0.12 sec
# ticker = GPS done in 0.22 sec
# ticker = GRMN done in 0.15 sec
# ticker = GS done in 0.17 sec
# ticker = GWW done in 0.23 sec
# ticker = HAL done in 0.32 sec
# ticker = HAS done in 0.25 sec
# ticker = HBAN done in 0.20 sec
# ticker = HBI done in 0.12 sec
# ticker = HCA done in 0.09 sec
# ticker = HD done in 0.26 sec
# ticker = HES done in 0.12 sec
# ticker = HIG done in 0.16 sec
# ticker = HII done in 0.11 sec
# ticker = HLT done in 0.08 sec
# ticker = HOLX done in 0.12 sec
# ticker = HON done in 0.31 sec
# ticker = HPE done in 0.07 sec
# ticker = HPQ done in 0.28 sec
# ticker = HRB done in 0.23 sec
# ticker = HRL done in 0.12 sec
# ticker = HSIC done in 0.16 sec
# ticker = HST done in 0.15 sec
# ticker = HSY done in 0.24 sec
# ticker = HUM done in 0.24 sec
# ticker = HWM done in 0.07 sec
# ticker = IBM done in 0.32 sec
# ticker = ICE done in 0.15 sec
# ticker = IDXX done in 0.14 sec
# ticker = IEX done in 0.11 sec
# ticker = IFF done in 0.26 sec
# ticker = ILMN done in 0.11 sec
# ticker = INCY done in 0.12 sec
# ticker = INFO done in 0.08 sec
# ticker = INTC done in 0.32 sec
# ticker = INTU done in 0.17 sec
# ticker = IP done in 0.30 sec
# ticker = IPG done in 0.19 sec
# ticker = IPGP done in 0.12 sec
# ticker = IQV done in 0.10 sec
# ticker = IR done in 0.07 sec
# ticker = IRM done in 0.14 sec
# ticker = ISRG done in 0.13 sec
# ticker = IT done in 0.14 sec
# ticker = ITW done in 0.22 sec
# ticker = IVZ done in 0.13 sec
# ticker = J done in 0.14 sec
# ticker = JBHT done in 0.13 sec
# ticker = JCI done in 0.21 sec
# ticker = JKHY done in 0.12 sec
# ticker = JNJ done in 0.30 sec
# ticker = JNPR done in 0.14 sec
# ticker = JPM done in 0.30 sec
# ticker = K done in 0.21 sec
# ticker = KEY done in 0.25 sec
# ticker = KEYS done in 0.07 sec
# ticker = KHC done in 0.07 sec
# ticker = KIM done in 0.12 sec
# ticker = KLAC done in 0.22 sec
# ticker = KMB done in 0.21 sec
# ticker = KMI done in 0.10 sec
# ticker = KMX done in 0.15 sec
# ticker = KO done in 0.28 sec
# ticker = KR done in 0.29 sec
# ticker = KSS done in 0.17 sec
# ticker = L done in 0.12 sec
# ticker = LDOS done in 0.14 sec
# ticker = LEG done in 0.22 sec
# ticker = LEN done in 0.12 sec
# ticker = LH done in 0.15 sec
# ticker = LHX done in 0.12 sec
# ticker = LIN done in 0.06 sec
# ticker = LKQ done in 0.12 sec
# ticker = LLY done in 0.24 sec
# ticker = LMT done in 0.25 sec
# ticker = LNC done in 0.27 sec
# ticker = LNT done in 0.12 sec
# ticker = LOW done in 0.21 sec
# ticker = LRCX done in 0.20 sec
# ticker = LUV done in 0.25 sec
# ticker = LVS done in 0.14 sec
# ticker = LW done in 0.07 sec
# ticker = LYB done in 0.09 sec
# ticker = LYV done in 0.11 sec
# ticker = MA done in 0.12 sec
# ticker = MAA done in 0.14 sec
# ticker = MAR done in 0.22 sec
# ticker = MAS done in 0.26 sec
# ticker = MCD done in 0.28 sec
# ticker = MCHP done in 0.17 sec
# ticker = MCK done in 0.19 sec
# ticker = MCO done in 0.14 sec
# ticker = MDLZ done in 0.11 sec
# ticker = MDT done in 0.26 sec
# ticker = MET done in 0.15 sec
# ticker = MGM done in 0.12 sec
# ticker = MHK done in 0.15 sec
# ticker = MKC done in 0.14 sec
# ticker = MKTX done in 0.12 sec
# ticker = MLM done in 0.14 sec
# ticker = MMC done in 0.20 sec
# ticker = MMM done in 0.27 sec
# ticker = MNST done in 0.10 sec
# ticker = MO done in 0.29 sec
# ticker = MOS done in 0.13 sec
# ticker = MPC done in 0.12 sec
# ticker = MRK done in 0.28 sec
# ticker = MRO done in 0.30 sec
# ticker = MS done in 0.12 sec
# ticker = MSCI done in 0.11 sec
# ticker = MSFT done in 0.22 sec
# ticker = MSI done in 0.12 sec
# ticker = MTB done in 0.18 sec
# ticker = MTD done in 0.14 sec
# ticker = MU done in 0.19 sec
# ticker = NCLH done in 0.09 sec
# ticker = NDAQ done in 0.12 sec
# ticker = NEE done in 0.14 sec
# ticker = NEM done in 0.24 sec
# ticker = NFLX done in 0.12 sec
# ticker = NI done in 0.22 sec
# ticker = NKE done in 0.19 sec
# ticker = NLOK done in 0.20 sec
# ticker = NLSN done in 0.10 sec
# ticker = NOC done in 0.24 sec
# ticker = NOV done in 0.14 sec
# ticker = NOW done in 0.08 sec
# ticker = NRG done in 0.12 sec
# ticker = NSC done in 0.22 sec
# ticker = NTAP done in 0.18 sec
# ticker = NTRS done in 0.19 sec
# ticker = NUE done in 0.25 sec
# ticker = NVDA done in 0.15 sec
# ticker = NVR done in 0.12 sec
# ticker = NWL done in 0.22 sec
# ticker = NWS done in 0.09 sec
# ticker = NWSA done in 0.08 sec
# ticker = O done in 0.12 sec
# ticker = ODFL done in 0.12 sec
# ticker = OKE done in 0.15 sec
# ticker = OMC done in 0.19 sec
# ticker = ORCL done in 0.19 sec
# ticker = ORLY done in 0.13 sec
# ticker = OTIS done in 0.05 sec
# ticker = OXY done in 0.22 sec
# ticker = PAYC done in 0.09 sec
# ticker = PAYX done in 0.21 sec
# ticker = PBCT done in 0.12 sec
# ticker = PCAR done in 0.23 sec
# ticker = PEAK done in 0.12 sec
# ticker = PEG done in 0.23 sec
# ticker = PEP done in 0.28 sec
# ticker = PFE done in 0.22 sec
# ticker = PFG done in 0.16 sec
# ticker = PG done in 0.29 sec
# ticker = PGR done in 0.21 sec
# ticker = PH done in 0.23 sec
# ticker = PHM done in 0.26 sec
# ticker = PKG done in 0.12 sec
# ticker = PKI done in 0.22 sec
# ticker = PLD done in 0.18 sec
# ticker = PM done in 0.13 sec
# ticker = PNC done in 0.21 sec
# ticker = PNR done in 0.14 sec
# ticker = PNW done in 0.24 sec
# ticker = PPG done in 0.23 sec
# ticker = PPL done in 0.22 sec
# ticker = PRGO done in 0.14 sec
# ticker = PRU done in 0.16 sec
# ticker = PSA done in 0.13 sec
# ticker = PSX done in 0.08 sec
# ticker = PVH done in 0.12 sec
# ticker = PWR done in 0.12 sec
# ticker = PXD done in 0.14 sec
# ticker = PYPL done in 0.07 sec
# ticker = QCOM done in 0.18 sec
# ticker = QRVO done in 0.08 sec
# ticker = RCL done in 0.14 sec
# ticker = RE done in 0.13 sec
# ticker = REG done in 0.12 sec
# ticker = REGN done in 0.12 sec
# ticker = RF done in 0.16 sec
# ticker = RHI done in 0.18 sec
# ticker = RJF done in 0.12 sec
# ticker = RL done in 0.15 sec
# ticker = RMD done in 0.14 sec
# ticker = ROK done in 0.22 sec
# ticker = ROL done in 0.13 sec
# ticker = ROP done in 0.13 sec
# ticker = ROST done in 0.22 sec
# ticker = RSG done in 0.12 sec
# ticker = RTX done in 0.29 sec
# ticker = SBAC done in 0.12 sec
# ticker = SBUX done in 0.20 sec
# ticker = SCHW done in 0.19 sec
# ticker = SEE done in 0.20 sec
# ticker = SHW done in 0.24 sec
# ticker = SIVB done in 0.12 sec
# ticker = SJM done in 0.12 sec
# ticker = SLB done in 0.23 sec
# ticker = SLG done in 0.12 sec
# ticker = SNA done in 0.22 sec
# ticker = SNPS done in 0.18 sec
# ticker = SO done in 0.22 sec
# ticker = SPG done in 0.20 sec
# ticker = SPGI done in 0.21 sec
# ticker = SRE done in 0.15 sec
# ticker = STE done in 0.14 sec
# ticker = STT done in 0.22 sec
# ticker = STX done in 0.14 sec
# ticker = STZ done in 0.14 sec
# ticker = SWK done in 0.21 sec
# ticker = SWKS done in 0.12 sec
# ticker = SYF done in 0.12 sec
# ticker = SYK done in 0.20 sec
# ticker = SYY done in 0.20 sec
# ticker = T done in 0.24 sec
# ticker = TAP done in 0.12 sec
# ticker = TDG done in 0.12 sec
# ticker = TDY done in 0.16 sec
# ticker = TEL done in 0.12 sec
# ticker = TFC done in 0.18 sec
# ticker = TFX done in 0.16 sec
# ticker = TGT done in 0.23 sec
# ticker = TJX done in 0.19 sec
# ticker = TMO done in 0.22 sec
# ticker = TMUS done in 0.11 sec
# ticker = TPR done in 0.12 sec
# ticker = TROW done in 0.22 sec
# ticker = TRV done in 0.14 sec
# ticker = TSCO done in 0.13 sec
# ticker = TSN done in 0.13 sec
# ticker = TT done in 0.21 sec
# ticker = TTWO done in 0.12 sec
# ticker = TWTR done in 0.08 sec
# ticker = TXN done in 0.25 sec
# ticker = TXT done in 0.22 sec
# ticker = TYL done in 0.14 sec
# ticker = UA done in 0.07 sec
# ticker = UAA done in 0.12 sec
# ticker = UAL done in 0.12 sec
# ticker = UDR done in 0.12 sec
# ticker = UHS done in 0.15 sec
# ticker = ULTA done in 0.11 sec
# ticker = UNH done in 0.22 sec
# ticker = UNM done in 0.23 sec
# ticker = UNP done in 0.23 sec
# ticker = UPS done in 0.16 sec
# ticker = URI done in 0.13 sec
# ticker = USB done in 0.19 sec
# ticker = V done in 0.12 sec
# ticker = VFC done in 0.26 sec
# ticker = VLO done in 0.12 sec
# ticker = VMC done in 0.22 sec
# ticker = VNO done in 0.12 sec
# ticker = VRSK done in 0.10 sec
# ticker = VRSN done in 0.15 sec
# ticker = VRTX done in 0.15 sec
# ticker = VTR done in 0.12 sec
# ticker = VZ done in 0.21 sec
# ticker = WAB done in 0.14 sec
# ticker = WAT done in 0.18 sec
# ticker = WBA done in 0.21 sec
# ticker = WDC done in 0.17 sec
# ticker = WEC done in 0.21 sec
# ticker = WELL done in 0.12 sec
# ticker = WFC done in 0.25 sec
# ticker = WHR done in 0.22 sec
# ticker = WM done in 0.14 sec
# ticker = WMB done in 0.23 sec
# ticker = WMT done in 0.28 sec
# ticker = WRB done in 0.14 sec
# ticker = WRK done in 0.07 sec
# ticker = WST done in 0.12 sec
# ticker = WU done in 0.13 sec
# ticker = WY done in 0.28 sec
# ticker = WYNN done in 0.12 sec
# ticker = XEL done in 0.16 sec
# ticker = XLNX done in 0.20 sec
# ticker = XOM done in 0.29 sec
# ticker = XRAY done in 0.19 sec
# ticker = XRX done in 0.25 sec
# ticker = XYL done in 0.11 sec
# ticker = YUM done in 0.17 sec
# ticker = ZBH done in 0.13 sec
# ticker = ZBRA done in 0.13 sec
# ticker = ZION done in 0.20 sec
# ticker = ZTS done in 0.09 sec
# number of tickers=500, calculations done in 85.74 sec

# %% [raw]
# number of tickers=488, calculations done in 91.39 sec
#
# number of tickers=500, calculations done in 85.74 sec
#
# select count(*) from quote_ta;
# --3154168

# %% [markdown]
# #### Create index after loading quotes

# %%
if FIRST_TIME:
    conn = sqlite3.connect(file_db)
    cur = conn.cursor()

    # Create table
    cur.execute(create_index_sql)

    conn.commit()
    conn.close()
